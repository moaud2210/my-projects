# %% [markdown]
#   # video game analysis
#
# ## This data is from kaggel which is an online community of data scientists and machine learning practitioners, started at 2010
# ### this excersies is from Jovian.ml which fliexble platform to learn data sceincse an d machin learning
# ### I run this data locally in my pc, i have anconda packedge and then uploaded to Jovian
# ### this data is in CSV format have 16598 rows × 11 columns

# %% [markdown]
# # upload the data

# %% [markdown]
# # first let us import some liberarys that we need it

# %%
import pandas as pd
import numpy as np

# %%
videogame_deital_df = pd.read_csv("F:/Downloads/data univ/videogsales.csv")

# %%
videogame_deital_df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Data Preparation and Cleaning
# ### to do that let us test our data to see if it need to fix in some area

# %% [markdown]
# ### we will just care about some intersting columns which is Name,Platform,Year,Genre,Publisher,Global_Sales.

# %%
selected_columns = ['Name','Platform','Year','Genre','Publisher','Global_Sales']
videogsales_df = videogame_deital_df[selected_columns]

# %% [markdown]
# ##### how the shape of our new dataframe

# %%
videogsales_df.shape
# Out:
# (16598, 6)

# %% [markdown]
# #### we will take sample to see how is our new dataframe

# %%
videogsales_df.sample(20)
# Out:
#                                                Name Platform    Year  \
# 11437          Steins;Gate: Hiyoku Renri no Darling     X360  2011.0
# 5842                                 Jumping Flash!       PS  1995.0
# 10813                                      MindJack     X360  2011.0
# 7900                          Tenchu: Fatal Shadows      PS2  2004.0
# 11004  Quiz Magic Academy DS: Futatsu no Jikuu Koku       DS  2010.0
# 5066                    Toukiden: The Age of Demons      PSV  2013.0
# 13418      Sesame Street: Elmo's A-to-Zoo Adventure       PC  2010.0
# 12148                                FIFA Soccer 06      GBA  2005.0
# 16299                    Moe Moe 2-Ji Daisenryaku 2      PSP  2010.0
# 4419                                      The Thing      PS2  2002.0
# 2431                          Need for Speed: Nitro      Wii  2009.0
# 5737      Tiny Toon Adventures: The Great Beanstalk       PS  1998.0
# 7923                             Zumba Fitness Rush     X360  2012.0
# ...

# %%
videogsales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  object
#  4   Publisher     16540 non-null  object
#  5   Global_Sales  16598 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 778.2+ KB

# %%
videogsales_df.describe()
# Out:
#                Year  Global_Sales
# count  16327.000000  16598.000000
# mean    2006.406443      0.537441
# std        5.828981      1.555028
# min     1980.000000      0.010000
# 25%     2003.000000      0.060000
# 50%     2007.000000      0.170000
# 75%     2010.000000      0.470000
# max     2020.000000     82.740000

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %% [markdown]
# ### I will use matplotlib.pyplot and seaborn to visualiz the data                                                                                         font size is 12 and transparent facecolor.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# ### let us start by exploratory the company Publish games

# %% [markdown]
# ## top 20 Publisher

# %%
top_20_Publisher = videogsales_df.Publisher.value_counts().head(20)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=88)
sns.barplot(top_20_Publisher.index,top_20_Publisher);

# %% [markdown]
# ### ubisoft is well known and it in top 4 Publisher

# %% [markdown]
# ### let us look at Distrbution of Platform

# %%
top_20_Platform = videogsales_df.Platform.value_counts().head(20)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.barplot(top_20_Platform
.index,top_20_Platform
);

# %% [markdown]
# #### of coures we don't see PS4 or PS5 in top 20 Platform maybe that because the most sales happend in old time in our data.

# %% [markdown]
# ##  Asking and Answering Questions
# ####  time to ask certain Questions  and looking for answer.

# %% [markdown]
# ### 1. what is popular game in our data ?

# %%
top_popular_game = videogsales_df.Name.value_counts().head(30)
top_popular_game
# Out:
# Need for Speed: Most Wanted                    12
# Madden NFL 07                                   9
# LEGO Marvel Super Heroes                        9
# Ratatouille                                     9
# FIFA 14                                         9
# LEGO Star Wars II: The Original Trilogy         8
# LEGO Harry Potter: Years 5-7                    8
# LEGO Jurassic World                             8
# Angry Birds Star Wars                           8
# LEGO The Hobbit                                 8
# Lego Batman 3: Beyond Gotham                    8
# Terraria                                        8
# Cars                                            8
# Monopoly                                        8
# Madden NFL 08                                   8
# The LEGO Movie Videogame                        8
# FIFA Soccer 13                                  8
# FIFA 15                                         8
# LEGO Indiana Jones: The Original Adventures     7
# ...

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.barplot(top_popular_game.index,top_popular_game);

# %% [markdown]
# ##### Need for Speed: Most Wanted is popular game in our data after that we can see alot of football games.

# %% [markdown]
# ### 2.which game have globa sales ?

# %%
GS = videogsales_df.Global_Sales.head(20)
GN = videogsales_df.Name.head(20)

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=75)
plt.plot(GN,GS);
plt.xlabel('GN')
plt.ylabel('GS')
# Out:
# Text(0, 0.5, 'GS')

# %% [markdown]
# ### As we expected super Mario game and GTA have Global spreed.

# %% [markdown]
# ### 3.what is types of game in our data and what in top and what in the last?

# %%
top_Genre = videogsales_df.Genre.value_counts()

# %%
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.barplot(top_20_Genre
.index,top_20_Genre
);

# %% [markdown]
# ### Action games is on top sales after that we see sports games just few games is puzzle.

# %% [markdown]
# ### 4.what is years most of the sales happaned in it ?

# %%
sales_Years = videogsales_df.Year.value_counts().head(20)
sales_Years
# Out:
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2012.0     657
# 2015.0     614
# 2014.0     582
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     344
# 1999.0     338
# 1997.0     289
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(15,8))
plt.figure(figsize=(15,8))
plt.xticks(rotation=90)
sns.barplot(sales_Years
.index,sales_Years
);

# %% [markdown]
# ### so most sales happend between 2007-2010. this is good point and that need more anaylsis.

# %% [markdown]
# ## Inferences and Conclusion

# %% [markdown]
# ### this data is pretty clean and easy to anaylsis and Visualized.
# ### Action and sport game is good field for video games company and video games maker.
# ### like any Business video games Business goes up and down.
# ### from 2000 to 200 video games Business is thrived but after that it decrease in this analysis we still don't know why?

# %% [markdown]
# ## References and Future Work

# %% [markdown]
# #### we need to add more data to our dataframe to countinue our analysis
